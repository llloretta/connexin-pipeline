# %% [markdown]
# # Extract sample planes to test pipeline (optional)

# %%
# imports
from pathlib import Path
BASE_DIR = Path.cwd().parent
from skimage import io

# %%
# load full image stack
cnx_img = io.imread(Path(BASE_DIR/'data/raw/corrected_images/cnx43.tif')) #full image

# %%
# save subset of 10 planes as test image stack 
io.imsave(Path(BASE_DIR/'data/raw/test_images/cnx_(158_160).tiff'), cnx_img[158:160, :, :])
